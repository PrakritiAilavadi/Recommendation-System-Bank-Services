# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\rbs\Downloads\transactions.xlsx')

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head(100)
# Out:
#         #  Date  Month  Time (hrs)  Customer ID  Income  Mortgage balance  \
# 0   18121    25     12          17            1    7543                 0
# 1   21235    21     10           9            1    7543                 0
# 2   24374    26      2           9            1    7543                 0
# 3   53803    18      8          19            1    7543                 0
# 4   82485     2      5          19            1    7543                 0
# ..    ...   ...    ...         ...          ...     ...               ...
# 95  52854     9      8          13            3     818                 0
# 96  74522    20      5          10            3     818                 0
# 97  77431    26      5          16            3     818                 0
# 98  82632     5      1          12            3     818                 0
# 99  92088    13      6          18            3     818                 0
#
#     Mortage payment  Utilities  Credit Card balance  Card payment  \
# ...

# %%
df.sort_values(by=['Customer ID', 'Month', 'Date', 'Time (hrs)'],ascending=[True,True,True,True])
# Out:
#              #  Date  Month  Time (hrs)  Customer ID  Income  \
# 25      278905     1      1          16            1    7543
# 31      354278     9      1          13            1    7543
# 17      178429    25      1          18            1    7543
# 28      314756    11      2          13            1    7543
# 44      478338    13      2          12            1    7543
# ...        ...   ...    ...         ...          ...     ...
# 499981  297989    21     11          18        10000    1004
# 499952   15609    27     11          18        10000    1004
# 499951    6751    10     12          10        10000    1004
# 499972  178074    14     12          15        10000    1004
# 499984  309948    24     12           9        10000    1004
#
#         Mortgage balance  Mortage payment  Utilities  Credit Card balance  \
# 25                     0              0.0        0.0                46260
# 31                     0              0.0        0.0                46260
# ...

# %%
conda install -c conda-forge tsfresh
# Out:
# ...
# Solving environment: ...working... failed with current_repodata.json, will retry with next repodata source.
# Initial quick solve with frozen env failed.  Unfreezing env and trying again.
# Solving environment: ...working... failed with current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\rbs\Anaconda3\envs\test1
#
#   added / updated specs:
#     - tsfresh
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-0.24.0          |        py37_1003         154 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         183 KB  conda-forge
#     certifi-2019.6.16          |           py37_1         149 KB  conda-forge
#     cffi-1.12.3                |   py37hb32ad35_0         219 KB  conda-forge
# ...

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\rbs\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.11               |           py37_0         3.0 MB
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.10-py37_0 --> 4.7.11-py37_0
#
#
#
# ...
#
# conda-4.7.11         | 3.0 MB    |            |   0%
# conda-4.7.11         | 3.0 MB    | 6          |   7%
# conda-4.7.11         | 3.0 MB    | ####3      |  44%
# conda-4.7.11         | 3.0 MB    | ########1  |  82%
# conda-4.7.11         | 3.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# ...

# %%
import tsfresh

# %%
# # df1['Date']+ ':' + df1['Month'] + df['Time (hrs)']
# # m=df['Time (hrs)'].apply(str)+':00:00'
# pd.to_datetime(df2['Date'].apply(str) + ':' + df2['Month'].apply(str) + '2018')

# %%
df2 = df[:1046]

# %%
label = df2['Mortgage balance']

# %%
label
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#          ...
# 1041    124092
# 1042    124092
# 1043    124092
# 1044    124092
# 1045    124092
# Name: Mortgage balance, Length: 1046, dtype: int64

# %%
df2 = df2.drop(['#','Date', 'Month', 'Time (hrs)', 'Other payment', 'Mortgage balance', 'Other payment type'], axis=1)

# %%
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features, extract_relevant_features, select_features


# features = impute(features)

# %%
df2
# Out:
#       Customer ID  Income  Mortage payment  Utilities  Credit Card balance  \
# 0               1    7543             0.00        0.0                46260
# 1               1    7543             0.00        0.0                46260
# 2               1    7543             0.00        0.0                46260
# 3               1    7543             0.00        0.0                46260
# 4               1    7543             0.00        0.0                46260
# ...           ...     ...              ...        ...                  ...
# 1041           20    4596          1240.92        0.0                44240
# 1042           20    4596             0.00        0.0                44240
# 1043           20    4596             0.00        0.0                44240
# 1044           20    4596             0.00        0.0                44240
# 1045           20    4596             0.00        0.0                44240
#
#       Card payment  Other payment amount
# ...

# %%
df2.apply(pd.to_numeric)
# Out:
#       Customer ID  Income  Mortage payment  Utilities  Credit Card balance  \
# 0               1    7543             0.00        0.0                46260
# 1               1    7543             0.00        0.0                46260
# 2               1    7543             0.00        0.0                46260
# 3               1    7543             0.00        0.0                46260
# 4               1    7543             0.00        0.0                46260
# ...           ...     ...              ...        ...                  ...
# 1041           20    4596          1240.92        0.0                44240
# 1042           20    4596             0.00        0.0                44240
# 1043           20    4596             0.00        0.0                44240
# 1044           20    4596             0.00        0.0                44240
# 1045           20    4596             0.00        0.0                44240
#
#       Card payment  Other payment amount
# ...

# %%
features = extract_features(df2,  column_id='Customer ID')         ## dataset needs a column id to be there
# Out:
# Feature Extraction:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
# Feature Extraction:  20%|██        | 1/5 [00:04<00:19,  4.76s/it]
#
#
#
#
# Feature Extraction:  40%|████      | 2/5 [00:08<00:12,  4.31s/it]
#
#
#
#
# Feature Extraction:  60%|██████    | 3/5 [00:11<00:08,  4.09s/it]
#
#
#
#
# Feature Extraction:  80%|████████  | 4/5 [00:15<00:03,  3.95s/it]
#
#
#
#
# Feature Extraction: 100%|██████████| 5/5 [00:18<00:00,  3.85s/it]

# %%
features
# Out:
# variable  Card payment__abs_energy  Card payment__absolute_sum_of_changes  \
# id
# 1                     2.275874e+06                                5280.10
# 2                     0.000000e+00                                   0.00
# 3                     3.345620e+04                                 736.20
# 4                     0.000000e+00                                   0.00
# 5                     1.668961e+06                                6303.28
# 6                     0.000000e+00                                   0.00
# 7                     6.146560e+03                                 305.76
# 8                     0.000000e+00                                   0.00
# 9                     3.505602e+05                                2201.76
# 10                    2.404118e+04                                 421.68
# 11                    0.000000e+00                                   0.00
# 12                    0.000000e+00                                   0.00
# ...

# %%
impute_extracted=impute(features)
# Out:
# C:\Users\rbs\Anaconda3\envs\test1\lib\site-packages\tsfresh\utilities\dataframe_functions.py:164: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
#   data = df.get_values()
# WARNING:tsfresh.utilities.dataframe_functions:The columns ['Card payment__fft_coefficient__coeff_36__attr_"abs"'
#  'Card payment__fft_coefficient__coeff_36__attr_"angle"'
#  'Card payment__fft_coefficient__coeff_36__attr_"imag"' ...
#  'Utilities__friedrich_coefficients__m_3__r_30__coeff_2'
#  'Utilities__friedrich_coefficients__m_3__r_30__coeff_3'
#  'Utilities__max_langevin_fixed_point__m_3__r_30'] did not have any finite values. Filling with zeros.

# %%
impute_extracted
# Out:
# variable  Card payment__abs_energy  Card payment__absolute_sum_of_changes  \
# id
# 1                     2.275874e+06                                5280.10
# 2                     0.000000e+00                                   0.00
# 3                     3.345620e+04                                 736.20
# 4                     0.000000e+00                                   0.00
# 5                     1.668961e+06                                6303.28
# 6                     0.000000e+00                                   0.00
# 7                     6.146560e+03                                 305.76
# 8                     0.000000e+00                                   0.00
# 9                     3.505602e+05                                2201.76
# 10                    2.404118e+04                                 421.68
# 11                    0.000000e+00                                   0.00
# 12                    0.000000e+00                                   0.00
# ...
